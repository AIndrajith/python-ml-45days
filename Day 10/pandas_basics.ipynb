# %%
import pandas as pd
import numpy as np

# %%
data = {
    "name": ["Alice", "Bob", "Charlie", "David"],
    "age": [25, 30, 35, 28],
    "score":[85, 90, 88, 92]
}

df = pd.DataFrame(data)
print(df.head())
# Out:
#       name  age  score
# 0    Alice   25     85
# 1      Bob   30     90
# 2  Charlie   35     88
# 3    David   28     92

# %%
filtered_df = df[df["age"] > 28]

print("Filtered (age > 28): ")
print(filtered_df)
# Out:
# Filtered (age > 28):
#       name  age  score
# 1      Bob   30     90
# 2  Charlie   35     88

# %%
df.loc[1, "age"] = np.nan
df.loc[3, "score"] = np.nan

print("With missing values: ")
print(df)
# Out:
# With missing values:
#       name   age  score  socre
# 0    Alice  25.0   85.0    NaN
# 1      Bob   NaN   90.0    NaN
# 2  Charlie  35.0   88.0    NaN
# 3    David  28.0    NaN    NaN

# %%
print("Missing values count: ")
print(df.isnull().sum())
# Out:
# Missing values count:
# name     0
# age      1
# score    0
# socre    4
# dtype: int64

# %%
df = df.drop(columns=["socre"])
print(df)
# Out:
#       name   age  score
# 0    Alice  25.0   85.0
# 1      Bob   NaN   90.0
# 2  Charlie  35.0   88.0
# 3    David  28.0    NaN

# %%
df["age"].fillna(df["age"].mean(),inplace=True)
df["score"].fillna(df["score"].mean(), inplace=True)
# Out:
# C:\Users\Avish\AppData\Local\Temp\ipykernel_3792\1849438001.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["age"].fillna(df["age"].mean(),inplace=True)
# C:\Users\Avish\AppData\Local\Temp\ipykernel_3792\1849438001.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["score"].fillna(df["score"].mean(), inplace=True)

# %%
print("After filling missing values: ")
print(df)
# Out:
# After filling missing values:
#       name        age      score
# 0    Alice  25.000000  85.000000
# 1      Bob  29.333333  90.000000
# 2  Charlie  35.000000  88.000000
# 3    David  28.000000  87.666667

# %%
df["passed"] = df["score"] >= 85

# features and target
X = df[["age", "score"]]
y = df[["passed"]]

print("Features (X):")
print(X)
# Out:
# Features (X):
#          age      score
# 0  25.000000  85.000000
# 1  29.333333  90.000000
# 2  35.000000  88.000000
# 3  28.000000  87.666667

# %%
print("Target(y):")
print(y)
# Out:
# Target(y):
#    passed
# 0    True
# 1    True
# 2    True
# 3    True
