# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    "age": [22, 25, 30, 35, 40, 45, 50],
    "salary": [30000, 35000, 50000, 60000, 65000, 70000, 120000],
    "experience": [1, 2, 5, 7, 10, 12, 20],
    "city": ["Colombo", "Kandy", "Colombo", "Galle", "Kandy", "Colombo", "Colombo"],
    "target": [0, 0, 1, 1, 1, 1, 1]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    age  salary  experience     city  target
# 0   22   30000           1  Colombo       0
# 1   25   35000           2    Kandy       0
# 2   30   50000           5  Colombo       1
# 3   35   60000           7    Galle       1
# 4   40   65000          10    Kandy       1
# 5   45   70000          12  Colombo       1
# 6   50  120000          20  Colombo       1

# %%
print("Head: ")
print(df.head())
# Out:
# Head:
#    age  salary  experience     city  target
# 0   22   30000           1  Colombo       0
# 1   25   35000           2    Kandy       0
# 2   30   50000           5  Colombo       1
# 3   35   60000           7    Galle       1
# 4   40   65000          10    Kandy       1

# %%
print("Info: ")
print(df.info())
# Out:
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         7 non-null      int64
#  1   salary      7 non-null      int64
#  2   experience  7 non-null      int64
#  3   city        7 non-null      object
#  4   target      7 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 412.0+ bytes
# None

# %%
print("Describe: ")
print(df.describe())
# Out:
# Describe:
#              age         salary  experience    target
# count   7.000000       7.000000    7.000000  7.000000
# mean   35.285714   61428.571429    8.142857  0.714286
# std    10.355583   29820.893922    6.568322  0.487950
# min    22.000000   30000.000000    1.000000  0.000000
# 25%    27.500000   42500.000000    3.500000  0.500000
# 50%    35.000000   60000.000000    7.000000  1.000000
# 75%    42.500000   67500.000000   11.000000  1.000000
# max    50.000000  120000.000000   20.000000  1.000000

# %%
# Histogram
df["salary"].hist(bins=10)
plt.title("Salary Distribution")
plt.xlabel("Salary")
plt.ylabel("Frequency")
plt.show()

# %%
# Boxplot
df.boxplot(column="salary")
plt.title("Salary Boxplot")
plt.show()

# %%
# Scatter plot
df.plot.scatter(x="experience", y="salary")
plt.title("Experience vs Salary")
plt.show()

# %%
# correlation matrix

corr = df.corr(numeric_only= True)
print("Correlation matrix: ")
print(corr)

sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
# Out:
# Correlation matrix:
#                  age    salary  experience    target
# age         1.000000  0.924046    0.969620  0.777472
# salary      0.924046  1.000000    0.985817  0.662689
# experience  0.969620  0.985817    1.000000  0.690882
# target      0.777472  0.662689    0.690882  1.000000

# %%
# value_counts()

print("City counts: ")
print(df["city"].value_counts())
# Out:
# City counts:
# city
# Colombo    4
# Kandy      2
# Galle      1
# Name: count, dtype: int64

# %%
# bar plots
df["city"].value_counts().plot(kind="bar")
plt.title("City Distribution")
plt.xlabel("City")
plt.ylabel("Count")
plt.show()

df["target"].value_counts().plot(kind="bar")
plt.title("Target Distribution")
plt.show()
